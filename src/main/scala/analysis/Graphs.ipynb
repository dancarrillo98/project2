# %%
import seaborn as s
import pandas as pd

# %%
q7 = pd.read_csv("q7.csv", header=None)

# %%
q7
# Out:
#              0                  1         2            3
# 0      Alabama            Vincent  0.780800   503.532740
# 1      Alabama           Flomaton  0.789490   566.050350
# 2      Alabama  Owens Cross Roads  0.994480  1531.917140
# 3      Alabama            Clayton  0.612710   459.747070
# 4      Alabama          Pell City  0.817360   774.585695
# ...        ...                ...       ...          ...
# 11271  Wyoming         Rock River  0.962790   776.023070
# 11272  Wyoming             Dubois  0.969210   631.378110
# 11273  Wyoming       Rock Srpings  0.953160  1138.337760
# 11274  Wyoming            Worland  0.846510   625.279170
# 11275  Wyoming            Laramie  0.961445   830.454123
#
# [11276 rows x 4 columns]

# %%
# make seaborn plot with 2 as x and 3 as y and each state being a different color
s.scatterplot(x=2, y=3,hue=0,data=q7, legend=False)
# Out:
# <AxesSubplot:xlabel='2', ylabel='3'>
